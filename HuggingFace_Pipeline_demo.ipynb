# %% [markdown]
# # Install packages

# %%
# !pip install transformers==4.32.0 accelerate tiktoken einops scipy transformers_stream_generator==0.0.4 peft deepspeed dataset SentencePiece
# Out:
# Collecting transformers==4.32.0
#   Downloading transformers-4.32.0-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.25.0)
# Collecting tiktoken
#   Downloading tiktoken-0.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 67.5 MB/s eta 0:00:00
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Collecting transformers_stream_generator==0.0.4
#   Downloading transformers-stream-generator-0.0.4.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Collecting peft
#   Downloading peft-0.6.2-py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.7/174.7 kB 19.2 MB/s eta 0:00:00
# Collecting deepspeed
#   Downloading deepspeed-0.12.4.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dataset
#   Downloading dataset-1.6.2-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.32.0)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 68.7 MB/s eta 0:00:00
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.32.0) (4.66.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu118)
# Collecting hjson (from deepspeed)
#   Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 7.2 MB/s eta 0:00:00
# Collecting ninja (from deepspeed)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 35.3 MB/s eta 0:00:00
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from deepspeed) (9.0.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from deepspeed) (1.10.13)
# Collecting pynvml (from deepspeed)
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.6 MB/s eta 0:00:00
# Collecting sqlalchemy<2.0.0,>=1.3.2 (from dataset)
#   Downloading SQLAlchemy-1.4.50-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.6 MB/s eta 0:00:00
# Collecting alembic>=0.6.2 (from dataset)
#   Downloading alembic-1.13.0-py3-none-any.whl (230 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.6/230.6 kB 28.3 MB/s eta 0:00:00
# Collecting banal>=1.0.1 (from dataset)
#   Downloading banal-1.0.6-py2.py3-none-any.whl (6.1 kB)
# Collecting Mako (from alembic>=0.6.2->dataset)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=0.6.2->dataset) (4.5.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.32.0) (2023.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.32.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.32.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.32.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.32.0) (2023.11.17)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<2.0.0,>=1.3.2->dataset) (3.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Building wheels for collected packages: transformers_stream_generator, deepspeed
#   Building wheel for transformers_stream_generator (setup.py) ... done
#   Created wheel for transformers_stream_generator: filename=transformers_stream_generator-0.0.4-py3-none-any.whl size=12316 sha256=d914a3925910e655b24d68e8351e0cad3ecf22a626d4148b351cde30944181aa
#   Stored in directory: /root/.cache/pip/wheels/47/1d/3c/92d88493ed40c0d9be60a391eb76c9a56e9f9b7542cb789401
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.12.4-py3-none-any.whl size=1290649 sha256=c4fe83459702261199a760c3386e7669d328891772ebb7d112159818b4206f9d
#   Stored in directory: /root/.cache/pip/wheels/7b/0c/52/f464610477b069120f740202a9d84a27f9d7235cbf035c4b75
# Successfully built transformers_stream_generator deepspeed
# Installing collected packages: tokenizers, ninja, hjson, banal, sqlalchemy, pynvml, Mako, einops, tiktoken, alembic, transformers, deepspeed, dataset, transformers_stream_generator, peft
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.0
#     Uninstalling tokenizers-0.15.0:
#       Successfully uninstalled tokenizers-0.15.0
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.23
#     Uninstalling SQLAlchemy-2.0.23:
#       Successfully uninstalled SQLAlchemy-2.0.23
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.50 which is incompatible.
# Successfully installed Mako-1.3.0 alembic-1.13.0 banal-1.0.6 dataset-1.6.2 deepspeed-0.12.4 einops-0.7.0 hjson-3.1.0 ninja-1.11.1.1 peft-0.6.2 pynvml-11.5.0 sqlalchemy-1.4.50 tiktoken-0.5.2 tokenizers-0.13.3 transformers-4.32.0 transformers_stream_generator-0.0.4

# %% [markdown]
# # Loading dataset

# %%
from datasets import load_dataset

dataset = load_dataset("Stevross/mmlu", "econometrics")

# %% [markdown]
# # Define utilities

# %%
from torch.utils.data import Dataset
# Question Answering
class KeyDatasetQA(Dataset):
    def __init__(self, dataset: Dataset, question: str, choices: str):
        self.dataset = dataset
        self.question = question
        self.choices = choices

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, i):
        output = ''
        for j, choice in enumerate(self.dataset[self.choices][i]):
            output += f'{str(j)}: {choice} '
        return self.dataset[self.question][i], output

# %%
from torch.utils.data import Dataset
# Text generation
class KeyDatasetTG(Dataset):
    def __init__(self, dataset: Dataset, question: str, choices: str):
        self.dataset = dataset
        self.question = question
        self.choices = choices

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, i):
        output = self.dataset[self.question][i]
        for j, choice in enumerate(self.dataset[self.choices][i]):
            output += f' {str(j)}: {choice} '
        output += ". The answer is "
        return output

# %%
# Return: accuracy
def evaluate(answers: list, model_answers: list):
  correct = 0
  for i in range(len(model_answers)):
    if str(answers[i]) == model_answers[i]:
      correct += 1
  return correct/len(model_answers)

# %% [markdown]
# # Models

# %% [markdown]
# ## vihangd/shearedplats-2.7b-v2

# %%
from transformers import pipeline

shearedplats = pipeline('text-generation', "vihangd/shearedplats-2.7b-v2", max_new_tokens = 1)
# Out:
# Loading checkpoint shards:   0%|          | 0/15 [00:00<?, ?it/s]

# %%
question = "Which one of the following is the most appropriate definition of a 99% confidence interval? 0: 99% of the time in repeated samples, the interval would contain the true value of the parameter, 1: 99% of the time in repeated samples, the interval would contain the estimated value of the parameter, 2: 99% of the time in repeated samples, the null hypothesis will be rejected, 3: 99% of the time in repeated samples, the null hypothesis will not be rejected when it was false .The answer is "
shearedplats(question)
# Out:
# [{'generated_text': 'Which one of the following is the most appropriate definition of a 99% confidence interval? 0: 99% of the time in repeated samples, the interval would contain the true value of the parameter, 1: 99% of the time in repeated samples, the interval would contain the estimated value of the parameter, 2: 99% of the time in repeated samples, the null hypothesis will be rejected, 3: 99% of the time in repeated samples, the null hypothesis will not be rejected when it was false .The answer is 2'}]

# %%
from transformers.pipelines.pt_utils import KeyDataset
from tqdm.auto import tqdm

# %%
model_out = []
model_answer = []
for out in tqdm(shearedplats(KeyDatasetTG(dataset["test"], 'question', 'choices'))):
  model_out.append(out)
  model_answer.append(out[0]['generated_text'][-1])
  print(out[0]['generated_text'][-1])
# Out:
#   0%|          | 0/114 [00:00<?, ?it/s]
# 2
# 1
# 2
# 0
# 2
# 2
# 1
# 0
# 1
# 2
# 1
# 1
# 2
# 2
# 1
# 2
# 2
# 1
# 1
# 3
# 0
# 2
# 2
# 1
# 2
# 2
# 1
# 1
# 2
# 0
# 2
# 2
# 2
# 0
# 2
# 1
# 2
# 1
# 1
# 2
# 1
# 2
# 1
# 0
# 1
# 1
# 2
# 1
# 1
# 2
# 0
# 1
# 2
# 2
# 2
# 1
# 2
# 2
# 2
# 2
# 1
# 0
# 2
# 3
# 1
# 2
# 1
# 2
# 1
# 2
# 2
# 2
# 1
# 2
# 0
# 2
# 2
# 2
# 1
# 3
# 1
# 1
# 3
# 0
# 2
# 1
# 1
# 2
# 0
# 1
# 2
# 0
# 0
# 2
# 2
# 2
# 3
# 2
# 0
# 0
#
#
# 0
# 1
# 2
# 2
# 1
# 0
# 2
# 0
# 1
# 3
# 2
# 1
# 2

# %%
evaluate(dataset['test']['answer'], model_answer)
# Out:
# 0.2543859649122807

# %% [markdown]
# ## vihangd/smartyplats-3b-v2

# %%
# !pip install SentencePiece
# Out:
# Collecting SentencePiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.9 MB/s eta 0:00:00
# Installing collected packages: SentencePiece
# Successfully installed SentencePiece-0.1.99

# %%
from transformers import pipeline

smartyplats = pipeline('text-generation', "vihangd/smartyplats-3b-v2", device_map="auto", use_fast = False, max_new_tokens = 1)
# Out:
# Loading checkpoint shards:   0%|          | 0/19 [00:00<?, ?it/s]
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the cpu.

# %%
question = "Which one of the following is the most appropriate definition of a 99% confidence interval? 0: 99% of the time in repeated samples, the interval would contain the true value of the parameter, 1: 99% of the time in repeated samples, the interval would contain the estimated value of the parameter, 2: 99% of the time in repeated samples, the null hypothesis will be rejected, 3: 99% of the time in repeated samples, the null hypothesis will not be rejected when it was false .The answer is "
smartyplats(question)
# Out:
# [{'generated_text': 'Which one of the following is the most appropriate definition of a 99% confidence interval? 0: 99% of the time in repeated samples, the interval would contain the true value of the parameter, 1: 99% of the time in repeated samples, the interval would contain the estimated value of the parameter, 2: 99% of the time in repeated samples, the null hypothesis will be rejected, 3: 99% of the time in repeated samples, the null hypothesis will not be rejected when it was false .The answer is 2'}]

# %%
from transformers.pipelines.pt_utils import KeyDataset
from tqdm.auto import tqdm

# %%
model_out = []
model_answer = []
for out in tqdm(smartyplats(KeyDatasetTG(dataset["test"], 'question', 'choices'))):
  model_out.append(out)
  model_answer.append(out[0]['generated_text'][-1])
  print(out[0]['generated_text'][-1])
# Out:
#   0%|          | 0/114 [00:00<?, ?it/s]
# 2
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 2
# 1
# 2
# 3
# 2
# 1
# 1
# 2
# 2
# 2
# 3
# 2
# 1
# 2
# 2
# 1
# 3
# 2
# 2
# 3
# 2
# 2
# 3
# 2
# 3
# 1
# 2
# 1
# 3
# 3
# 2
# 2
# 2
# 1
# 4
# 2
# 2
# 3
# 2
# 1
# 1
# 3
# 3
# 2
# 2
# 2
# 2
# 1
# 2
# 1
# 3
# 2
# 2
# 2
# 2
# 3
# 3
# 3
# 3
# 3
# 2
# 2
# 2
# 1
# 3
# 2
# 2
# 1
# 3
# 3
# 2
# 2
# 2
# 1
# 1
# 2
# 2
# 2
# 3
# 2
# 3
# 3
# 3
# 2
# 2
# 3
# 2
# 0
# 3
# 1
# 2
# 3
# 2
# 2
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3

# %%
# Return: accuracy
def evaluate(answers: list, model_answers: list):
  correct = 0
  for i in range(len(model_answers)):
    if str(answers[i]) == model_answers[i]:
      correct += 1
  return correct/len(model_answers)

# %%
evaluate(dataset['test']['answer'], model_answer)
# Out:
# 0.23684210526315788

# %% [markdown]
# ## timpal0l/mdeberta-v3-base-squad2

# %%
from transformers import pipeline

qa_model = pipeline("question-answering", "timpal0l/mdeberta-v3-base-squad2", max_length = 1)
# Out:
# config.json:   0%|          | 0.00/879 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# {'score': 0.00012132546544307843, 'start': 0, 'end': 1, 'answer': '0'}

# %%
from transformers.pipelines.pt_utils import KeyDataset
from tqdm.auto import tqdm

# %%
for q, c in KeyDatasetQA(dataset["test"], 'question', 'choices'):
  out = qa_model(q, c)
  print(out)
# Out:
# {'score': 0.0001011548301903531, 'start': 0, 'end': 2, 'answer': '0:'}
# {'score': 0.15939778089523315, 'start': 325, 'end': 367, 'answer': ' PP tests have good power in small samples'}
# {'score': 0.4679064154624939, 'start': 115, 'end': 138, 'answer': ' symmetrical about zero'}
# {'score': 0.0012031022924929857, 'start': 0, 'end': 2, 'answer': '0:'}
# {'score': 6.35853098174266e-07, 'start': 103, 'end': 161, 'answer': ' In theory, the sample could be larger than the population'}
# {'score': 0.001884917262941599, 'start': 286, 'end': 340, 'answer': ' null hypothesis of zero autocorrelation coefficients.'}
# {'score': 2.0826997570111416e-05, 'start': 33, 'end': 91, 'answer': ' Includes as few variables as possible to explain the data'}
# {'score': 4.8342636560505525e-09, 'start': 242, 'end': 253, 'answer': ' fat-tailed'}
# {'score': 0.005365314427763224, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 0.15942007303237915, 'start': 0, 'end': 15, 'answer': '0: Less than -1'}
# {'score': 3.211125942925719e-08, 'start': 0, 'end': 16, 'answer': '0: (ii) and (iv)'}
# {'score': 0.0001529911969555542, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 0.06968570500612259, 'start': 53, 'end': 118, 'answer': ' Mis-specified models are certain to produce inaccurate forecasts'}
# {'score': 2.605558258039764e-08, 'start': 81, 'end': 126, 'answer': ' Different models from within the ARMA family'}
# {'score': 2.3962407794897445e-05, 'start': 126, 'end': 163, 'answer': ' Residuals that are all close to zero'}
# {'score': 0.00010052932339021936, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 6.726012884428201e-07, 'start': 61, 'end': 75, 'answer': ' (iii) only 3:'}
# {'score': 7.547262612206396e-06, 'start': 155, 'end': 159, 'answer': ' y_t'}
# {'score': 0.004158878233283758, 'start': 0, 'end': 8, 'answer': '0: T x k'}
# {'score': 3.2771140467957594e-06, 'start': 10, 'end': 23, 'answer': ' 1: 1 and 0.5'}
# {'score': 1.6556745308093923e-08, 'start': 104, 'end': 159, 'answer': ' The explanatory variable is correlated with the errors'}
# {'score': 0.5491011142730713, 'start': 151, 'end': 183, 'answer': ' The test result is inconclusive'}
# {'score': 0.001322128577157855, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 0.020539410412311554, 'start': 0, 'end': 48, 'answer': '0: It will be consistent, unbiased and efficient'}
# {'score': 1.609204446140211e-05, 'start': 49, 'end': 65, 'answer': ' Test statistics'}
# {'score': 0.1593789905309677, 'start': 28, 'end': 33, 'answer': ' Zero'}
# {'score': 1.3550816220231354e-05, 'start': 207, 'end': 258, 'answer': ' nether necessary nor sufficient for identification'}
# {'score': 0.0002947979373857379, 'start': 198, 'end': 207, 'answer': ' unbiased'}
# {'score': 3.333966014906764e-05, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 0.0006751852342858911, 'start': 150, 'end': 166, 'answer': ' SRF and the PRF'}
# {'score': 0.016514627262949944, 'start': 63, 'end': 82, 'answer': ' coefficient biases'}
# {'score': 0.0023099055979400873, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 0.009737529791891575, 'start': 98, 'end': 146, 'answer': ' Unbiased but inconsistent coefficient estimates'}
# {'score': 0.012183877639472485, 'start': 47, 'end': 84, 'answer': ' A model that contains many variables'}
# {'score': 4.6889363147784024e-05, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 8.997076292871498e-07, 'start': 212, 'end': 236, 'answer': ' outside the unit circle'}
# {'score': 0.03585747256875038, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 4.548492142930627e-07, 'start': 64, 'end': 126, 'answer': ' mean of each entity away from each observation on that entity'}
# {'score': 3.090862037424813e-07, 'start': 164, 'end': 225, 'answer': ' there is no autocorrelation in the test regression residuals'}
# {'score': 0.1517694890499115, 'start': 28, 'end': 40, 'answer': ' Zero 2: One'}
# {'score': 0.00041589949978515506, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 0.03562824800610542, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 0.0003675753250718117, 'start': 190, 'end': 226, 'answer': ' VARs often produce better forecasts'}
# {'score': 0.001095257350243628, 'start': 9, 'end': 25, 'answer': ' null hypothesis'}
# {'score': 5.179978870728519e-06, 'start': 118, 'end': 125, 'answer': ' p lags'}
# {'score': 1.2995545148442034e-05, 'start': 10, 'end': 31, 'answer': ' 1.71 2: 2.06 3: 1.96'}
# {'score': 0.03515797108411789, 'start': 0, 'end': 8, 'answer': '0: 77.07'}
# {'score': 0.0466402992606163, 'start': 2, 'end': 39, 'answer': ' They are not theoretically motivated'}
# {'score': 2.0872734239674173e-05, 'start': 0, 'end': 16, 'answer': '0: (ii) and (iv)'}
# {'score': 0.029747826978564262, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 0.003433665493503213, 'start': 0, 'end': 2, 'answer': '0:'}
# {'score': 0.15819057822227478, 'start': 51, 'end': 79, 'answer': ' deterministic trend process'}
# {'score': 0.01091764960438013, 'start': 0, 'end': 2, 'answer': '0:'}
# {'score': 0.2258555144071579, 'start': 235, 'end': 258, 'answer': ' dimensionality problem'}
# {'score': 1.8412585234273138e-07, 'start': 32, 'end': 38, 'answer': ' (iii)'}
# {'score': 5.5612626965739764e-06, 'start': 0, 'end': 16, 'answer': '0: (ii) and (iv)'}
# {'score': 7.479427586076781e-05, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 7.1314660843313504e-09, 'start': 180, 'end': 194, 'answer': ' non-zero mean'}
# {'score': 0.04700570926070213, 'start': 0, 'end': 37, 'answer': '0: Close to zero 1: Close to plus one'}
# {'score': 0.0004006606759503484, 'start': 37, 'end': 75, 'answer': ' Zero skewness and a kurtosis of three'}
# {'score': 4.016043476440245e-06, 'start': 77, 'end': 107, 'answer': ' The OLS estimator is unbiased'}
# {'score': 0.03300108760595322, 'start': 106, 'end': 128, 'answer': ' 3: They have no trend'}
# {'score': 0.001485292101278901, 'start': 0, 'end': 28, 'answer': '0: (ii) and (iv) only 1: (i)'}
# {'score': 0.04347962513566017, 'start': 240, 'end': 267, 'answer': ' loss of degrees of freedom'}
# {'score': 0.06356541067361832, 'start': 42, 'end': 57, 'answer': ' H1 is rejected'}
# {'score': 0.007265930995345116, 'start': 0, 'end': 45, 'answer': '0: Discrete 1: Cardinal 2: Ordinal 3: Nominal'}
# {'score': 0.01725248247385025, 'start': 17, 'end': 31, 'answer': ' The largest 2'}
# {'score': 0.15813326835632324, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 0.1082085594534874, 'start': 175, 'end': 196, 'answer': ' take the square root'}
# {'score': 0.005243467167019844, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 5.273864758237323e-07, 'start': 2, 'end': 16, 'answer': ' (ii) and (iv)'}
# {'score': 0.0008895377977751195, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 0.011960063129663467, 'start': 187, 'end': 228, 'answer': ' Remove any large outliers from the data.'}
# {'score': 4.253475651694316e-07, 'start': 118, 'end': 168, 'answer': ' Heteroscedasticity and autocorrelation consistent'}
# {'score': 0.0004577237996272743, 'start': 78, 'end': 81, 'answer': ' 1:'}
# {'score': 0.0027325968258082867, 'start': 26, 'end': 68, 'answer': ' Uncorrelated 2: Independent 3: Fat-tailed'}
# {'score': 0.01196258794516325, 'start': 0, 'end': 28, 'answer': '0: (ii) and (iv) only 1: (i)'}
# {'score': 0.031956739723682404, 'start': 27, 'end': 48, 'answer': ' Multinomial variable'}
# {'score': 2.7960323834008705e-08, 'start': 193, 'end': 198, 'answer': ' 2SLS'}
# {'score': 4.696182713814778e-06, 'start': 0, 'end': 8, 'answer': '0: T x k'}
# {'score': 0.015005026012659073, 'start': 0, 'end': 21, 'answer': '0: 12 1: 4 2: 3 3: 36'}
# {'score': 5.8204750530421734e-05, 'start': 107, 'end': 163, 'answer': ' The sum of the RSS for the first and second sub-samples'}
# {'score': 4.023201108793728e-05, 'start': 96, 'end': 112, 'answer': ' null hypothesis'}
# {'score': 3.543066497968539e-07, 'start': 39, 'end': 75, 'answer': ' Drop one of the collinear variables'}
# {'score': 7.869451110309456e-06, 'start': 66, 'end': 99, 'answer': ' Stationary and unit root process'}
# {'score': 0.5255082249641418, 'start': 62, 'end': 87, 'answer': ' The Breusch-Godfrey test'}
# {'score': 5.914123448746977e-07, 'start': 69, 'end': 117, 'answer': ' The difference between the fitted value, y-hat,'}
# {'score': 0.00012753292685374618, 'start': 81, 'end': 98, 'answer': ' It is impossible'}
# {'score': 7.559952663882541e-09, 'start': 118, 'end': 143, 'answer': ' double-logarithmic model'}
# {'score': 0.14498279988765717, 'start': 4, 'end': 16, 'answer': ' logit model'}
# {'score': 0.0001296416885452345, 'start': 71, 'end': 74, 'answer': ' 3:'}
# {'score': 0.30715882778167725, 'start': 358, 'end': 369, 'answer': ' (a) to (c)'}
# {'score': 1.7691694154109427e-07, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 0.17819586396217346, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 0.0001282704179175198, 'start': 0, 'end': 2, 'answer': '0:'}
# {'score': 0.0010803869226947427, 'start': 93, 'end': 116, 'answer': ' pure time series model'}
# {'score': 1.001261153987798e-07, 'start': 2, 'end': 16, 'answer': ' More negative'}
# {'score': 0.00015340570826083422, 'start': 0, 'end': 16, 'answer': '0: (ii) and (iv)'}
# {'score': 0.0014969292096793652, 'start': 291, 'end': 306, 'answer': ' asymmetrically'}
# {'score': 5.7447890867479146e-05, 'start': 9, 'end': 11, 'answer': ' 1'}
# {'score': 7.277127588167787e-05, 'start': 0, 'end': 2, 'answer': '0:'}
# {'score': 0.0020618417765945196, 'start': 117, 'end': 158, 'answer': ' It is equivalent to the size of the test'}
# {'score': 0.005163656547665596, 'start': 47, 'end': 63, 'answer': ' 3: (-5.46,2.86)'}
# {'score': 0.029902467504143715, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 7.44227654649876e-05, 'start': 0, 'end': 2, 'answer': '0:'}
# {'score': 0.002469593659043312, 'start': 25, 'end': 47, 'answer': ' 2: 1, 2 and 3 only 3:'}
# {'score': 0.045649752020835876, 'start': 63, 'end': 143, 'answer': ' How well the sample regression function fits the population regression function'}
# {'score': 0.17639130353927612, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
# {'score': 2.0238772776792757e-05, 'start': 143, 'end': 174, 'answer': ' Mean absolute percentage error'}
# {'score': 1.1033353075617924e-06, 'start': 0, 'end': 2, 'answer': '0:'}
# {'score': 0.0023946671281009912, 'start': 9, 'end': 12, 'answer': ' No'}
# {'score': 0.004247945733368397, 'start': 0, 'end': 2, 'answer': '0:'}
# {'score': 0.0013603480765596032, 'start': 36, 'end': 71, 'answer': ' The variables are not cointegrated'}
# {'score': 0.006450730375945568, 'start': 0, 'end': 24, 'answer': '0: (ii) and (iv) only 1:'}
